# %%
import pickle

# %%
data = pickle.load(open("/home/iindyk/PycharmProjects/my_GAN/ImageNet/train_data_batch_1", "rb"))

# %%
print(data.keys())
# Out:
# dict_keys(['data', 'labels'])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-158dd995b57b> in <module>()
# ----> 1 print(data.keys()['labels'])
#
# TypeError: 'dict_keys' object is not subscriptable

# %%
print(data['labels'])
# Out:
# [372, 814, 227, 604, 226, 51, 663, 308, 276, 749, 384, 95, 357, 772, 665, 896, 189, 856, 664, 771, 407, 451, 647, 896, 14, 230, 603, 181, 860, 387, 351, 134, 363, 901, 856, 44, 245, 746, 940, 349, 475, 132, 167, 935, 1, 443, 970, 606, 138, 500, 929, 598, 484, 639, 958, 738, 205, 733, 513, 703, 310, 556, 977, 1, 754, 180, 803, 78, 969, 291, 684, 706, 330, 977, 34, 674, 179, 257, 731, 731, 639, 898, 149, 930, 418, 721, 175, 19, 326, 13, 836, 358, 288, 606, 618, 489, 351, 566, 504, 220, 49, 560, 956, 348, 222, 606, 745, 57, 790, 466, 158, 123, 464, 642, 978, 913, 433, 458, 417, 648, 504, 762, 297, 983, 650, 332, 429, 912, 179, 81, 669, 348, 634, 540, 378, 588, 21, 424, 714, 478, 126, 345, 204, 303, 136, 704, 640, 768, 769, 670, 832, 653, 60, 341, 356, 367, 66, 947, 967, 444, 77, 670, 41, 996, 90, 203, 411, 93, 556, 816, 495, 611, 866, 737, 913, 59, 446, 936, 456, 229, 683, 620, 709, 164, 406, 114, 111, 884, 297, 43, 592, 711, 286, 360, 395, 739, 113, 926, 695, 6, 373, 675, 672, 166, 280
# ...

# %%
print(data['data'][0])
# Out:
# [102 115 123 ...  28  29  28]

# %%
import matplotlib.pyplot as plt

# %%
img = data['data'][0]

# %%
import numpy as np

# %%
img = np.reshape(np.array(img), newshape=(64, 64, 3))

# %%
plt.imsave('/home/iindyk/PycharmProjects/my_GAN/123.jpeg', img)

# %%
img = np.reshape(np.array(data['data'][100]), newshape=(64, 64, 3))
plt.imsave('/home/iindyk/PycharmProjects/my_GAN/123.jpeg', img)

# %%
img = np.reshape(np.array(data['data'][10]), newshape=(64, 64, 3))
plt.imsave('/home/iindyk/PycharmProjects/my_GAN/123.jpeg', img)

# %%
img = np.reshape(np.array(data['data'][100]), newshape=(64, 64, 3), order='F')
plt.imsave('/home/iindyk/PycharmProjects/my_GAN/123.jpeg', img)

# %%
print(len(data['labels']))
# Out:
# 128116

# %%
unique, counts = np.unique(np.array(data['labels']), return_counts=True)

# %%
freq = dict(zip(unique, counts))

# %%
print(freq)
# Out:
# {1: 140, 2: 126, 3: 131, 4: 146, 5: 138, 6: 84, 7: 107, 8: 112, 9: 133, 10: 133, 11: 130, 12: 119, 13: 136, 14: 142, 15: 123, 16: 130, 17: 145, 18: 105, 19: 110, 20: 131, 21: 121, 22: 132, 23: 122, 24: 135, 25: 129, 26: 120, 27: 113, 28: 108, 29: 140, 30: 133, 31: 72, 32: 118, 33: 126, 34: 127, 35: 129, 36: 138, 37: 138, 38: 138, 39: 121, 40: 129, 41: 131, 42: 74, 43: 136, 44: 124, 45: 136, 46: 85, 47: 142, 48: 133, 49: 125, 50: 110, 51: 137, 52: 113, 53: 111, 54: 139, 55: 130, 56: 129, 57: 126, 58: 143, 59: 126, 60: 130, 61: 130, 62: 135, 63: 135, 64: 133, 65: 146, 66: 134, 67: 117, 68: 132, 69: 138, 70: 102, 71: 126, 72: 96, 73: 129, 74: 126, 75: 110, 76: 130, 77: 134, 78: 126, 79: 142, 80: 127, 81: 122, 82: 152, 83: 126, 84: 110, 85: 133, 86: 133, 87: 136, 88: 156, 89: 81, 90: 132, 91: 135, 92: 136, 93: 117, 94: 121, 95: 139, 96: 134, 97: 142, 98: 115, 99: 65, 100: 123, 101: 135, 102: 132, 103: 131, 104: 121, 105: 121, 106: 125, 107: 118, 108: 130, 109: 117, 110: 130, 111: 122, 11
# ...

# %%
data.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-61149e794762> in <module>()
# ----> 1 data.close()
#
# AttributeError: 'dict' object has no attribute 'close'
